# %%
import pandas as pd

# %%
users = pd.read_csv('./data/all_users.csv')
users = users[['id','first_name','last_name','username','email','role','share_count']]
users
# Out:
#        id  first_name                 last_name              username  \
# 0       1     Michael                    Dadzie             afrobeezy
# 1       2        John                       Doe                  doey
# 2       3        John                       Doe                 doeyy
# 3       4        John                       Doe                doeyyy
# 4       5      Sachin                     Kinha                 kinha
# ..    ...         ...                       ...                   ...
# 995  1015  yjnywzpbwc  privaterelay.appleid.com  yjnywzpbwc_08c9i6l7f
# 996  1016  xkzvdj57xj  privaterelay.appleid.com  xkzvdj57xj_09f7c9l8i
# 997  1017       Nuage               Laboratoire       nuage_08i0l4c5f
# 998  1018  2mhdbqqk6q  privaterelay.appleid.com  2mhdbqqk6q_06l6f3i1c
# 999  1019  4nk89yj727  privaterelay.appleid.com  4nk89yj727_01l4f9c7i
#
#                                                  email role  share_count
# ...

# %%
users.describe()
# Out:
#                 id  share_count
# count  1000.000000       1000.0
# mean    510.122000          0.0
# std     293.581486          0.0
# min       1.000000          0.0
# 25%     256.750000          0.0
# 50%     511.500000          0.0
# 75%     762.250000          0.0
# max    1019.000000          0.0

# %%
liked = pd.read_csv('./data/liked_posts.csv')
liked = liked[['post_id','user_id','liked_at']]
liked
# Out:
#      post_id  user_id             liked_at
# 0         26        9  2023-10-24 19:28:41
# 1         33        9  2023-10-26 09:08:32
# 2         36        1  2023-10-28 09:08:35
# 3         36       16  2023-10-28 09:15:57
# 4         52        9  2023-10-30 15:48:46
# ..       ...      ...                  ...
# 995     1062      912  2024-08-09 13:15:14
# 996     1104      917  2024-08-09 13:27:55
# 997     1098      917  2024-08-09 13:28:08
# 998     1099        1  2024-08-09 16:44:25
# 999     1110      920  2024-08-10 18:43:07
#
# [1000 rows x 3 columns]

# %%
rated = pd.read_csv('./data/rated_posts.csv')
rated = rated[['post_id','user_id','rating_percent','rated_at']]
rated
# Out:
#      post_id  user_id  rating_percent             rated_at
# 0        516        1              64  2024-01-11 12:45:41
# 1        160        1              62  2024-01-11 12:47:15
# 2         19        1              20  2024-01-11 12:47:28
# 3        148        1             100  2024-01-11 12:49:35
# 4        513        1              63  2024-01-11 12:50:58
# ..       ...      ...             ...                  ...
# 995      142      487              20  2024-06-20 09:58:48
# 996      516      487              19  2024-06-20 09:58:49
# 997      150      487              19  2024-06-20 09:58:51
# 998      779      487              17  2024-06-20 09:58:52
# 999      165      487              23  2024-06-20 09:58:55
#
# [1000 rows x 4 columns]

# %%
viewed = pd.read_csv('./data/viewed_posts.csv')
viewed = viewed[['post_id','user_id','viewed_at']]
viewed
# Out:
#      post_id  user_id            viewed_at
# 0        631      114  2024-01-10 07:20:55
# 1        626      114  2024-01-10 07:21:18
# 2        571      114  2024-01-10 07:22:02
# 3        558      116  2024-01-10 12:33:47
# 4        551      116  2024-01-10 12:33:55
# ..       ...      ...                  ...
# 995      161      368  2024-06-17 16:49:41
# 996      143      368  2024-06-17 16:49:42
# 997      151      368  2024-06-17 16:49:42
# 998      159      370  2024-06-17 16:50:02
# 999      560      370  2024-06-17 16:50:07
#
# [1000 rows x 3 columns]

# %%
inspired = pd.read_csv('./data/inspired_posts.csv')
inspired
# Out:
#       id  post_id  user_id          inspired_at
# 0      1      588        1  2023-12-31 09:06:27
# 1      2      152        1  2023-12-31 09:07:32
# 2      3      415        1  2023-12-31 09:10:09
# 3      4      558        1  2023-12-31 09:11:23
# 4      5      549        1  2023-12-31 09:11:28
# ..   ...      ...      ...                  ...
# 198  212     1251       18  2024-11-20 21:19:13
# 199  213     1340     1123  2024-11-23 17:31:50
# 200  214       64        1  2024-11-29 11:29:04
# 201  215     1365        5  2024-11-29 19:10:45
# 202  216     1316     1010  2024-12-05 09:10:36
#
# [203 rows x 4 columns]

# %%
posts = pd.read_csv('./data/posts_features.csv')
posts
# Out:
#        id  category_id                                              title  \
# 0      11            2                            Recipe for a flow state
# 1      12            2                                      Why fit in..?
# 2      13            2                           Transcending Singularity
# 3      14            2                                  Peak Performance?
# 4      15            2                          Our Existential Situation
# ..    ...          ...                                                ...
# 995  1332           13  Kalsubai is the highest peak in Maharashtra, s...
# 996  1334           13  Tap into the magic of winter. .Sometimes, all ...
# 997  1335           13     anzeige -- ️From idea to masterpiece ️with the
# 998  1336           13  In the heart of darkness, magic is our only sh...
# 999  1338           13                    crypto VFX animation art work!!
#
#                                             video_link  \
# ...

# %%
import json 

with open('./data/all_posts.json') as f:
    data = json.load(f)
posts = (data['posts'])

# %%
for i in posts:
    print(i['post_summary']['emotions'])
# Out:
# {'conveyed': ['enthusiasm', 'engagement', 'curiosity', 'passion']}
# {'expressed_emotions': ['Anger', 'Determination', 'Pain', 'Empowerment', 'Isolation']}
# {'emotional_content': ['Wonder', 'Intensity', 'Compassion', 'Engagement', 'Contemplation']}
# {'moods': ['excitement', 'passion', 'contemplation']}
# {'conveyed_emotions': ['Concern', 'Passion', 'Reflectiveness', 'Urgency', 'Hope mingled with disappointment']}
# {'moods': ['frustration', 'confusion']}
# {'conveyed': ['contemplation', 'determination', 'vulnerability']}
# {'conveyed_emotions': ['wonder', 'curiosity', 'reflection', 'passion']}
# ['Encouragement', 'Urgency', 'Warmth', 'Inspiration']
# ['Intensity', 'Focus', 'Elation', 'Determination', 'Camaraderie']
# ['Confidence', 'Urgency', 'Relatability', 'Positivity', 'Engagement']
# ['warmth', 'inspiration', 'encouragement', 'joy', 'thoughtfulness']
# {'conveyed_emotions': ['determination', 'encouragement', 'friendliness', 'seriousness', 'enthusiasm']}
# ...
